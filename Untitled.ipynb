# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from datetime import datetime
import math

# %%
# Reading the Dataset
df = pd.read_csv('datasets/dataset_1.csv')

# %%
df.head()
# Out:
#         Date  Time (Local)  Eyeballs   Zeroes   Completed Trips   Requests   \
# 0  10-Sep-12             7          5        0                 2          2
# 1        NaN             8          6        0                 2          2
# 2        NaN             9          8        3                 0          0
# 3        NaN            10          9        2                 0          1
# 4        NaN            11         11        1                 4          4
#
#    Unique Drivers
# 0               9
# 1              14
# 2              14
# 3              14
# 4              11

# %%
df.shape
# Out:
# (336, 7)

# %%
df['Date'].isnull().sum()
# Out:
# 321

# %%
df = df.fillna(method = 'ffill')

# %%
df.columns
# Out:
# Index(['Date', 'Time (Local)', 'Eyeballs ', 'Zeroes ', 'Completed Trips ',
#        'Requests ', 'Unique Drivers'],
#       dtype='object')

# %% [markdown]
# ## Finding the date with most completed trips

# %%
df[['Date','Completed Trips ']].groupby(by = 'Date').sum().sort_values(by = 'Completed Trips ',ascending = False)
# Out:
#            Completed Trips
# Date
# 22-Sep-12               248
# 15-Sep-12               199
# 21-Sep-12               190
# 23-Sep-12               111
# 14-Sep-12               108
# 16-Sep-12                93
# 12-Sep-12                91
# 20-Sep-12                70
# 17-Sep-12                57
# 13-Sep-12                45
# 18-Sep-12                42
# 19-Sep-12                41
# 11-Sep-12                40
# 10-Sep-12                26
# 24-Sep-12                 4

# %% [markdown]
# ### As we can see that 22 Sep is the date on which there were most completed trips

# %% [markdown]
# ## Finding the maximum number of trips completed in a 24 hour period

# %%
df['Time (Local)'] = df['Time (Local)'].astype(str)
df['Datetime'] =  df['Date']+ ' '+ df['Time (Local)']

# %%
df['Datetime']
# Out:
# 0       10-Sep-12 7
# 1       10-Sep-12 8
# 2       10-Sep-12 9
# 3      10-Sep-12 10
# 4      10-Sep-12 11
#            ...
# 331     24-Sep-12 2
# 332     24-Sep-12 3
# 333     24-Sep-12 4
# 334     24-Sep-12 5
# 335     24-Sep-12 6
# Name: Datetime, Length: 336, dtype: object

# %%
df['Datetime'] = df['Datetime'].apply(lambda x: datetime.strptime(x,'%d-%b-%y %H'))

# %%
df['Datetime']
# Out:
# 0     2012-09-10 07:00:00
# 1     2012-09-10 08:00:00
# 2     2012-09-10 09:00:00
# 3     2012-09-10 10:00:00
# 4     2012-09-10 11:00:00
#               ...
# 331   2012-09-24 02:00:00
# 332   2012-09-24 03:00:00
# 333   2012-09-24 04:00:00
# 334   2012-09-24 05:00:00
# 335   2012-09-24 06:00:00
# Name: Datetime, Length: 336, dtype: datetime64[ns]

# %%
trips_by_time = df[['Datetime','Completed Trips ']]

# %%
trips_by_time = trips_by_time.set_index('Datetime')

# %%
trips_by_time
# Out:
#                      Completed Trips
# Datetime
# 2012-09-10 07:00:00                 2
# 2012-09-10 08:00:00                 2
# 2012-09-10 09:00:00                 0
# 2012-09-10 10:00:00                 0
# 2012-09-10 11:00:00                 4
# ...                               ...
# 2012-09-24 02:00:00                 0
# 2012-09-24 03:00:00                 0
# 2012-09-24 04:00:00                 0
# 2012-09-24 05:00:00                 1
# 2012-09-24 06:00:00                 2
#
# [336 rows x 1 columns]

# %%
indexer = pd.api.indexers.FixedForwardWindowIndexer(window_size=24)
df_agg_twentyfour_hrs = df.set_index("Datetime").rolling(window=indexer, min_periods=1).sum()
df_agg_twentyfour_hrs.nlargest(1, 'Completed Trips ')
# Out:
# /var/folders/zq/z9tt8wfn4psfglvz008pzfpm0000gn/T/ipykernel_2213/2884333849.py:2: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['Date'], dtype='object')
#   df_agg_twentyfour_hrs = df.set_index("Datetime").rolling(window=indexer, min_periods=1).sum()
#                      Time (Local)  Eyeballs   Zeroes   Completed Trips   \
# Datetime
# 2012-09-21 17:00:00         276.0     1015.0    207.0             278.0
#
#                      Requests   Unique Drivers
# Datetime
# 2012-09-21 17:00:00      367.0           349.0

# %% [markdown]
# ### As we can see in the above table that maximum number of completed trips in 24 hours occurred in the hour starting from 2012-09-21 17:00:00

# %% [markdown]
# ## Finding the hour with most requests

# %%
df.groupby(by = 'Time (Local)').sum().sort_values(by = 'Requests ')
# Out:
#               Eyeballs   Zeroes   Completed Trips   Requests   Unique Drivers
# Time (Local)
# 4                    29       21                 2          9               9
# 5                    42       31                 4         14              11
# 7                   111       30                19         22              60
# 9                   202       39                20         26             110
# 10                  243       46                18         28             129
# 6                    78       32                19         28              37
# 8                   151       30                24         29              95
# 3                    83       30                21         35              40
# 11                  264       47                36         47             133
# 12                  278       41                46         53             132
# 13                  311       67                44         55             122
# 14                  332       61                49         71             125
# 15                  337       70                47         71             139
# 16                  358       61                68         82             144
# 1                   207       43                71         96              94
# 17                  408       74                78         98             165
# 2                   170       52                61        100              62
# 20                  410       61                76        107             163
# 21                  459       68                88        112             155
# 18                  447       74                92        119             174
# 0                   339       81               102        142             111
# 19                  448       96               120        156             180
# 22                  492       81               134        174             144
# 23                  488      193               126        184             119

# %% [markdown]
# ### As we can see in the table above that the maximum number of requests have been raised at the 24th hour( 11:00 p.m.-12:00 a.m.).

# %% [markdown]
# ## Finding all zeroes during weekends

# %%
df['Date'].dtype
# Out:
# dtype('O')

# %%
df
# Out:
#           Date Time (Local)  Eyeballs   Zeroes   Completed Trips   Requests   \
# 0    10-Sep-12            7          5        0                 2          2
# 1    10-Sep-12            8          6        0                 2          2
# 2    10-Sep-12            9          8        3                 0          0
# 3    10-Sep-12           10          9        2                 0          1
# 4    10-Sep-12           11         11        1                 4          4
# ..         ...          ...        ...      ...               ...        ...
# 331  24-Sep-12            2          3        3                 0          2
# 332  24-Sep-12            3          3        3                 0          1
# 333  24-Sep-12            4          1        1                 0          0
# 334  24-Sep-12            5          4        2                 1          1
# 335  24-Sep-12            6          9        1                 2          2
#
#      Unique Drivers            Datetime
# 0                 9 2012-09-10 07:00:00
# 1                14 2012-09-10 08:00:00
# 2                14 2012-09-10 09:00:00
# 3                14 2012-09-10 10:00:00
# 4                11 2012-09-10 11:00:00
# ..              ...                 ...
# 331               0 2012-09-24 02:00:00
# 332               0 2012-09-24 03:00:00
# 333               0 2012-09-24 04:00:00
# 334               3 2012-09-24 05:00:00
# 335               7 2012-09-24 06:00:00
#
# [336 rows x 8 columns]

# %%
weekdays = ['Mon','Tue','Wed','Thurs','Fri','Sat','Sun']
df_dates = df.copy()
df_dates['Date']
df_dates['day'] = df_dates['Date'].apply(lambda x: weekdays[datetime.strptime(x,'%d-%b-%y').weekday()])

# %%
df_weekend = df_dates[df_dates['day'].isin(['Fri','Sat','Sun'])]

# %%
df_weekend['Time (Local)'] = df_weekend['Time (Local)'].astype(int)
drop_ride = df_weekend[(df_weekend['Time (Local)']<17) & (df_weekend['day']=='Fri')].index
df_week = df_weekend.drop(drop_ride)
# Out:
# /var/folders/zq/z9tt8wfn4psfglvz008pzfpm0000gn/T/ipykernel_2213/3952437751.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_weekend['Time (Local)'] = df_weekend['Time (Local)'].astype(int)

# %%
df_week
# Out:
#           Date  Time (Local)  Eyeballs   Zeroes   Completed Trips   Requests   \
# 106  14-Sep-12            17         34        4                 3          5
# 107  14-Sep-12            18         40        2                 8          9
# 108  14-Sep-12            19         46        6                 9         10
# 109  14-Sep-12            20         38        4                 8          9
# 110  14-Sep-12            21         49        6                 8          9
# ..         ...           ...        ...      ...               ...        ...
# 324  23-Sep-12            19         32        9                 4          6
# 325  23-Sep-12            20         29        6                 3          3
# 326  23-Sep-12            21         24        6                 3          4
# 327  23-Sep-12            22         17        2                 2          2
# 328  23-Sep-12            23          9        3                 3          3
#
#      Unique Drivers            Datetime  day
# 106              13 2012-09-14 17:00:00  Fri
# 107              14 2012-09-14 18:00:00  Fri
# 108              15 2012-09-14 19:00:00  Fri
# 109              14 2012-09-14 20:00:00  Fri
# 110              17 2012-09-14 21:00:00  Fri
# ..              ...                 ...  ...
# 324              11 2012-09-23 19:00:00  Sun
# 325               7 2012-09-23 20:00:00  Sun
# 326               5 2012-09-23 21:00:00  Sun
# 327               6 2012-09-23 22:00:00  Sun
# 328               3 2012-09-23 23:00:00  Sun
#
# [110 rows x 9 columns]

# %%
drop_ride = df_weekend[(df_weekend['Time (Local)']>3) & (df_weekend['day']=='Sun')].index
df_week = df_week.drop(drop_ride)

# %%
df_week
# Out:
#           Date  Time (Local)  Eyeballs   Zeroes   Completed Trips   Requests   \
# 106  14-Sep-12            17         34        4                 3          5
# 107  14-Sep-12            18         40        2                 8          9
# 108  14-Sep-12            19         46        6                 9         10
# 109  14-Sep-12            20         38        4                 8          9
# 110  14-Sep-12            21         49        6                 8          9
# ..         ...           ...        ...      ...               ...        ...
# 304  22-Sep-12            23         99       59                25         44
# 305  23-Sep-12             0         62       25                23         32
# 306  23-Sep-12             1         38        1                15         23
# 307  23-Sep-12             2         34        4                13         18
# 308  23-Sep-12             3         19        1                 9          9
#
#      Unique Drivers            Datetime  day
# 106              13 2012-09-14 17:00:00  Fri
# 107              14 2012-09-14 18:00:00  Fri
# 108              15 2012-09-14 19:00:00  Fri
# 109              14 2012-09-14 20:00:00  Fri
# 110              17 2012-09-14 21:00:00  Fri
# ..              ...                 ...  ...
# 304              17 2012-09-22 23:00:00  Sat
# 305              18 2012-09-23 00:00:00  Sun
# 306              18 2012-09-23 01:00:00  Sun
# 307              18 2012-09-23 02:00:00  Sun
# 308              16 2012-09-23 03:00:00  Sun
#
# [70 rows x 9 columns]

# %%
(df_week['Zeroes '].sum()/df['Zeroes '].sum())*100
# Out:
# 45.066480055983206

# %% [markdown]
# ### As we see around 45.1% of all Zeroes are present on weekends

# %% [markdown]
# ## Finding the weighted average of completed trips per driver

# %%
df['trips_per_driver'] = df['Completed Trips ']/df['Unique Drivers']

# %%
df_without_zero_drivers = df[df['Unique Drivers']>0]

# %%
df_without_zero_drivers
# Out:
#           Date Time (Local)  Eyeballs   Zeroes   Completed Trips   Requests   \
# 0    10-Sep-12            7          5        0                 2          2
# 1    10-Sep-12            8          6        0                 2          2
# 2    10-Sep-12            9          8        3                 0          0
# 3    10-Sep-12           10          9        2                 0          1
# 4    10-Sep-12           11         11        1                 4          4
# ..         ...          ...        ...      ...               ...        ...
# 327  23-Sep-12           22         17        2                 2          2
# 328  23-Sep-12           23          9        3                 3          3
# 329  24-Sep-12            0          7        2                 1          2
# 334  24-Sep-12            5          4        2                 1          1
# 335  24-Sep-12            6          9        1                 2          2
#
#      Unique Drivers            Datetime  trips_per_driver
# 0                 9 2012-09-10 07:00:00          0.222222
# 1                14 2012-09-10 08:00:00          0.142857
# 2                14 2012-09-10 09:00:00          0.000000
# 3                14 2012-09-10 10:00:00          0.000000
# 4                11 2012-09-10 11:00:00          0.363636
# ..              ...                 ...               ...
# 327               6 2012-09-23 22:00:00          0.333333
# 328               3 2012-09-23 23:00:00          1.000000
# 329               2 2012-09-24 00:00:00          0.500000
# 334               3 2012-09-24 05:00:00          0.333333
# 335               7 2012-09-24 06:00:00          0.285714
#
# [297 rows x 9 columns]

# %%
weighted_avg = np.average(df_without_zero_drivers['trips_per_driver'],weights = df_without_zero_drivers['Completed Trips '])

# %%
weighted_avg
# Out:
# 0.8282775715092395

# %% [markdown]
# ### We can observe that the weighted average is 0.828

# %% [markdown]
# ## Finding the busiest 8 hour shift

# %%
df.head()
# Out:
#         Date Time (Local)  Eyeballs   Zeroes   Completed Trips   Requests   \
# 0  10-Sep-12            7          5        0                 2          2
# 1  10-Sep-12            8          6        0                 2          2
# 2  10-Sep-12            9          8        3                 0          0
# 3  10-Sep-12           10          9        2                 0          1
# 4  10-Sep-12           11         11        1                 4          4
#
#    Unique Drivers            Datetime  trips_per_driver
# 0               9 2012-09-10 07:00:00          0.222222
# 1              14 2012-09-10 08:00:00          0.142857
# 2              14 2012-09-10 09:00:00          0.000000
# 3              14 2012-09-10 10:00:00          0.000000
# 4              11 2012-09-10 11:00:00          0.363636

# %%
df_eight_hrs = df.set_index('Datetime').resample('8H').sum()

# %%
df_eight_hrs.sort_values(by = 'Requests ',ascending = False)
# Out:
#                      Eyeballs   Zeroes   Completed Trips   Requests   \
# Datetime
# 2012-09-21 16:00:00        515       88               153        192
# 2012-09-22 16:00:00        469      113               127        175
# 2012-09-15 16:00:00        436      152               112        170
# 2012-09-14 16:00:00        353       46                81         95
# 2012-09-22 08:00:00        325       78                70         91
# 2012-09-23 00:00:00        178       50                63         90
# 2012-09-22 00:00:00        166       28                51         78
# 2012-09-15 00:00:00        155       34                63         74
# 2012-09-20 16:00:00        232       33                53         68
# 2012-09-16 00:00:00        142       23                51         64
# 2012-09-12 08:00:00        213       15                52         60
# 2012-09-17 16:00:00        207       36                42         53
# 2012-09-23 16:00:00        200       39                34         43
# 2012-09-12 16:00:00        171       24                33         41
# 2012-09-11 16:00:00        173       41                30         39
# 2012-09-15 08:00:00        197       72                24         38
# 2012-09-13 16:00:00        168       22                28         37
# 2012-09-18 16:00:00        157       42                25         35
# 2012-09-16 16:00:00        150       35                25         32
# 2012-09-19 16:00:00        173       21                24         31
# 2012-09-21 08:00:00        172       24                21         28
# 2012-09-18 00:00:00         59       35                 8         28
# 2012-09-16 08:00:00        134       35                17         22
# 2012-09-14 08:00:00        146       22                16         21
# 2012-09-14 00:00:00         50       24                11         21
# 2012-09-23 08:00:00        148       26                14         21
# 2012-09-10 16:00:00        106       16                15         21
# 2012-09-21 00:00:00         53       12                16         20
# 2012-09-18 08:00:00        126       17                 9         18
# 2012-09-13 08:00:00        117       30                14         18
# 2012-09-20 08:00:00        117       21                12         17
# 2012-09-19 08:00:00        112       21                11         15
# 2012-09-17 08:00:00        125       19                10         14
# 2012-09-12 00:00:00         39       16                 6         13
# 2012-09-13 00:00:00         40       28                 3         12
# 2012-09-10 08:00:00         78       10                 9         11
# 2012-09-17 00:00:00         45       21                 5         11
# 2012-09-20 00:00:00         26       14                 5         10
# 2012-09-24 00:00:00         34       19                 4          8
# 2012-09-19 00:00:00         34        4                 6          8
# 2012-09-11 00:00:00         33       12                 5          7
# 2012-09-11 08:00:00        108       11                 5          6
# 2012-09-10 00:00:00          5        0                 2          2
#
#                      Unique Drivers  trips_per_driver
# Datetime
# 2012-09-21 16:00:00             198          6.357265
# 2012-09-22 16:00:00             142          7.314552
# 2012-09-15 16:00:00             107          8.299235
# 2012-09-14 16:00:00             121          4.997644
# 2012-09-22 08:00:00              77          6.780556
# 2012-09-23 00:00:00              77          5.395833
# 2012-09-22 00:00:00              73               NaN
# 2012-09-15 00:00:00              59          5.335526
# 2012-09-20 16:00:00              88          4.667347
# 2012-09-16 00:00:00              53          3.921429
# 2012-09-12 08:00:00             113          3.766558
# 2012-09-17 16:00:00              73          4.563148
# 2012-09-23 16:00:00              67          4.361905
# 2012-09-12 16:00:00              76          3.704240
# 2012-09-11 16:00:00              57          4.145887
# 2012-09-15 08:00:00              27          6.933333
# 2012-09-13 16:00:00              77          3.806061
# 2012-09-18 16:00:00              48          4.489683
# 2012-09-16 16:00:00              59          3.758333
# 2012-09-19 16:00:00              91          2.326282
# 2012-09-21 08:00:00              73          1.992857
# 2012-09-18 00:00:00              13          3.350000
# 2012-09-16 08:00:00              38          3.740476
# 2012-09-14 08:00:00              74          1.779870
# 2012-09-14 00:00:00              16          4.900000
# 2012-09-23 08:00:00              60          1.751984
# 2012-09-10 16:00:00              40          3.047619
# 2012-09-21 00:00:00              27          2.025397
# 2012-09-18 08:00:00              73          1.030159
# 2012-09-13 08:00:00              76          1.461111
# 2012-09-20 08:00:00              80          1.205988
# 2012-09-19 08:00:00              75          1.311147
# 2012-09-17 08:00:00              72          1.072222
# 2012-09-12 00:00:00              12          2.000000
# 2012-09-13 00:00:00               6          1.250000
# 2012-09-10 08:00:00              89          0.831169
# 2012-09-17 00:00:00              19          1.050000
# 2012-09-20 00:00:00              11          1.500000
# 2012-09-24 00:00:00              12          1.119048
# 2012-09-19 00:00:00              20          2.685714
# 2012-09-11 00:00:00              17          1.400000
# 2012-09-11 08:00:00              58          0.690079
# 2012-09-10 00:00:00               9          0.222222

# %% [markdown]
# ### We can observe that the maximum number of requests are in the interval 2012-09-21 16:00:00 - 2012-09-22 00:00:00. Also note that the top 4 total number of requests are all starting from 16:00 hrs so we can infer that it is the busiest 8 hour shift

# %% [markdown]
# ## Comparing the driver supply and trip demand over the two weeks

# %%
df_eight_hrs[['Requests ','Unique Drivers']].plot()
plt.show()

# %% [markdown]
# ### From the above graph it seems the supply of drivers increase with the increase in demand

# %% [markdown]
# ## Finding the 72 hour period with the highest Zeroes to Eyeballs ratio

# %%
indexer = pd.api.indexers.FixedForwardWindowIndexer(window_size=72)
df_agg_three_days = df.set_index("Datetime").rolling(window=indexer, min_periods=1).sum().reset_index()
df_agg_three_days['zeros_to_eyeballs_ratio'] = df_agg_three_days['Zeroes '] / df_agg_three_days['Eyeballs ']
# Out:
# /var/folders/zq/z9tt8wfn4psfglvz008pzfpm0000gn/T/ipykernel_2213/1657940379.py:2: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['Date'], dtype='object')
#   df_agg_three_days = df.set_index("Datetime").rolling(window=indexer, min_periods=1).sum().reset_index()

# %%
df_agg_three_days = df_agg_three_days[df_agg_three_days['Datetime'] <= (df_agg_three_days['Datetime'].max() - pd.Timedelta(days=3))]

time_format = "%Y/%m/%d %H:%M"
df_agg_three_days['Time Interval']  = df_agg_three_days['Datetime'].dt.strftime(time_format) +  "-" + (df_agg_three_days['Datetime'] + pd.Timedelta('3 days')).dt.strftime(time_format)
df_agg_three_days
# Out:
#                Datetime  Time (Local)  Eyeballs   Zeroes   Completed Trips   \
# 0   2012-09-10 07:00:00         828.0      956.0    172.0             159.0
# 1   2012-09-10 08:00:00         828.0      961.0    173.0             158.0
# 2   2012-09-10 09:00:00         828.0      964.0    174.0             157.0
# 3   2012-09-10 10:00:00         828.0      970.0    175.0             157.0
# 4   2012-09-10 11:00:00         828.0      976.0    176.0             159.0
# ..                  ...           ...        ...      ...               ...
# 259 2012-09-21 02:00:00         828.0     2209.0    465.0             535.0
# 260 2012-09-21 03:00:00         828.0     2207.0    468.0             534.0
# 261 2012-09-21 04:00:00         828.0     2207.0    468.0             534.0
# 262 2012-09-21 05:00:00         828.0     2208.0    469.0             534.0
# 263 2012-09-21 06:00:00         828.0     2211.0    470.0             535.0
#
#      Requests   Unique Drivers  trips_per_driver  zeros_to_eyeballs_ratio  \
# 0        211.0           473.0         20.807776                 0.179916
# 1        210.0           468.0         20.835553                 0.180021
# 2        209.0           462.0         20.817696                 0.180498
# 3        209.0           457.0         20.817696                 0.180412
# 4        210.0           453.0         21.017696                 0.180328
# ..         ...             ...               ...                      ...
# 259      724.0           780.0         39.191989                 0.210502
# 260      724.0           775.0         38.991989                 0.212053
# 261      725.0           775.0         38.991989                 0.212053
# 262      725.0           775.0         38.991989                 0.212409
# 263      726.0           778.0         39.325323                 0.212573
#
#                          Time Interval
# 0    2012/09/10 07:00-2012/09/13 07:00
# 1    2012/09/10 08:00-2012/09/13 08:00
# 2    2012/09/10 09:00-2012/09/13 09:00
# 3    2012/09/10 10:00-2012/09/13 10:00
# 4    2012/09/10 11:00-2012/09/13 11:00
# ..                                 ...
# 259  2012/09/21 02:00-2012/09/24 02:00
# 260  2012/09/21 03:00-2012/09/24 03:00
# 261  2012/09/21 04:00-2012/09/24 04:00
# 262  2012/09/21 05:00-2012/09/24 05:00
# 263  2012/09/21 06:00-2012/09/24 06:00
#
# [264 rows x 10 columns]

# %%
df_agg_three_days.nlargest(1, 'zeros_to_eyeballs_ratio')
# Out:
#                Datetime  Time (Local)  Eyeballs   Zeroes   Completed Trips   \
# 118 2012-09-15 05:00:00         828.0     1495.0    438.0             292.0
#
#      Requests   Unique Drivers  trips_per_driver  zeros_to_eyeballs_ratio  \
# 118      431.0           454.0         37.088176                 0.292977
#
#                          Time Interval
# 118  2012/09/15 05:00-2012/09/18 05:00

# %% [markdown]
# ### The interval shown in the above row has the maximum ratio of zeroes to eyeball 0.293. It is for the 72 hour interval from 2012-09-15 05:00:00 - 2012-09-18 05:00:00

# %% [markdown]
# ## Finding the busiest hour in the two weeks with a highest demand to supply ratio

# %%
df['Time (Local)'].dtype
# Out:
# dtype('O')

# %%
df['Time (Local)'] = df['Time (Local)'].astype(int)

# %%
df_agg = df.groupby(by = 'Time (Local)').sum()

# %%
df_agg
# Out:
#               Eyeballs   Zeroes   Completed Trips   Requests   Unique Drivers  \
# Time (Local)
# 0                   339       81               102        142             111
# 1                   207       43                71         96              94
# 2                   170       52                61        100              62
# 3                    83       30                21         35              40
# 4                    29       21                 2          9               9
# 5                    42       31                 4         14              11
# 6                    78       32                19         28              37
# 7                   111       30                19         22              60
# 8                   151       30                24         29              95
# 9                   202       39                20         26             110
# 10                  243       46                18         28             129
# 11                  264       47                36         47             133
# 12                  278       41                46         53             132
# 13                  311       67                44         55             122
# 14                  332       61                49         71             125
# 15                  337       70                47         71             139
# 16                  358       61                68         82             144
# 17                  408       74                78         98             165
# 18                  447       74                92        119             174
# 19                  448       96               120        156             180
# 20                  410       61                76        107             163
# 21                  459       68                88        112             155
# 22                  492       81               134        174             144
# 23                  488      193               126        184             119
#
#               trips_per_driver
# Time (Local)
# 0                     8.519786
# 1                     7.555952
# 2                     7.588889
# 3                     2.133929
# 4                     2.000000
# 5                          NaN
# 6                     6.152381
# 7                     5.157937
# 8                     4.293543
# 9                     3.340476
# 10                    2.752778
# 11                    4.081692
# 12                    5.078788
# 13                    5.403175
# 14                    5.223052
# 15                    4.174008
# 16                    6.238654
# 17                    6.537607
# 18                    7.254788
# 19                    8.939336
# 20                    6.203090
# 21                    8.135092
# 22                   11.261326
# 23                   11.269306

# %%
df_agg['eyeball_to_driver'] = df_agg['Eyeballs ']/df_agg['Unique Drivers']

# %%
df_agg.sort_values(by = 'eyeball_to_driver')
# Out:
#               Eyeballs   Zeroes   Completed Trips   Requests   Unique Drivers  \
# Time (Local)
# 8                   151       30                24         29              95
# 9                   202       39                20         26             110
# 7                   111       30                19         22              60
# 10                  243       46                18         28             129
# 11                  264       47                36         47             133
# 3                    83       30                21         35              40
# 12                  278       41                46         53             132
# 6                    78       32                19         28              37
# 1                   207       43                71         96              94
# 15                  337       70                47         71             139
# 17                  408       74                78         98             165
# 16                  358       61                68         82             144
# 19                  448       96               120        156             180
# 20                  410       61                76        107             163
# 13                  311       67                44         55             122
# 18                  447       74                92        119             174
# 14                  332       61                49         71             125
# 2                   170       52                61        100              62
# 21                  459       68                88        112             155
# 0                   339       81               102        142             111
# 4                    29       21                 2          9               9
# 22                  492       81               134        174             144
# 5                    42       31                 4         14              11
# 23                  488      193               126        184             119
#
#               trips_per_driver  eyeball_to_driver
# Time (Local)
# 8                     4.293543           1.589474
# 9                     3.340476           1.836364
# 7                     5.157937           1.850000
# 10                    2.752778           1.883721
# 11                    4.081692           1.984962
# 3                     2.133929           2.075000
# 12                    5.078788           2.106061
# 6                     6.152381           2.108108
# 1                     7.555952           2.202128
# 15                    4.174008           2.424460
# 17                    6.537607           2.472727
# 16                    6.238654           2.486111
# 19                    8.939336           2.488889
# 20                    6.203090           2.515337
# 13                    5.403175           2.549180
# 18                    7.254788           2.568966
# 14                    5.223052           2.656000
# 2                     7.588889           2.741935
# 21                    8.135092           2.961290
# 0                     8.519786           3.054054
# 4                     2.000000           3.222222
# 22                   11.261326           3.416667
# 5                          NaN           3.818182
# 23                   11.269306           4.100840

# %% [markdown]
# ### As we see in the above table the hour starting at 23:00 has the highest ratio of eyeballs to unique drivers. This is the hour at which we should add more drivers to decrease this ratio

# %% [markdown]
# ## Finding out if the data available is for exactly to weeks

# %%
df_sorted = df.sort_values(by = 'Datetime')

# %%
df_sorted
# Out:
#           Date  Time (Local)  Eyeballs   Zeroes   Completed Trips   Requests   \
# 0    10-Sep-12             7          5        0                 2          2
# 1    10-Sep-12             8          6        0                 2          2
# 2    10-Sep-12             9          8        3                 0          0
# 3    10-Sep-12            10          9        2                 0          1
# 4    10-Sep-12            11         11        1                 4          4
# ..         ...           ...        ...      ...               ...        ...
# 331  24-Sep-12             2          3        3                 0          2
# 332  24-Sep-12             3          3        3                 0          1
# 333  24-Sep-12             4          1        1                 0          0
# 334  24-Sep-12             5          4        2                 1          1
# 335  24-Sep-12             6          9        1                 2          2
#
#      Unique Drivers            Datetime  trips_per_driver
# 0                 9 2012-09-10 07:00:00          0.222222
# 1                14 2012-09-10 08:00:00          0.142857
# 2                14 2012-09-10 09:00:00          0.000000
# 3                14 2012-09-10 10:00:00          0.000000
# 4                11 2012-09-10 11:00:00          0.363636
# ..              ...                 ...               ...
# 331               0 2012-09-24 02:00:00               NaN
# 332               0 2012-09-24 03:00:00               NaN
# 333               0 2012-09-24 04:00:00               NaN
# 334               3 2012-09-24 05:00:00          0.333333
# 335               7 2012-09-24 06:00:00          0.285714
#
# [336 rows x 9 columns]

# %%
total_time_difference = df_sorted['Datetime'].iloc[-1] - df_sorted['Datetime'].iloc[0]

# %%
total_time_difference
# Out:
# Timedelta('13 days 23:00:00')

# %% [markdown]
# ### The total time covered by the records is 1 hour less than 2 weeks

# %% [markdown]
# ## Finding the hour with the least supply and least demand

# %%
print ("minimum supply :")
print ("\n")
print (df_agg[df_agg['Unique Drivers']==min(df_agg['Unique Drivers'])])
print ("\n")
print ("minimum demand")
print ("\n")
print (df_agg[df_agg['Eyeballs ']==min(df_agg['Eyeballs '])])
# Out:
# minimum supply :
#
#
#               Eyeballs   Zeroes   Completed Trips   Requests   Unique Drivers  \
# Time (Local)
# 4                    29       21                 2          9               9
#
#               trips_per_driver  eyeball_to_driver
# Time (Local)
# 4                          2.0           3.222222
#
#
# minimum demand
#
#
#               Eyeballs   Zeroes   Completed Trips   Requests   Unique Drivers  \
# Time (Local)
# 4                    29       21                 2          9               9
#
#               trips_per_driver  eyeball_to_driver
# Time (Local)
# 4                          2.0           3.222222

# %%
df
# Out:
#           Date  Time (Local)  Eyeballs   Zeroes   Completed Trips   Requests   \
# 0    10-Sep-12             7          5        0                 2          2
# 1    10-Sep-12             8          6        0                 2          2
# 2    10-Sep-12             9          8        3                 0          0
# 3    10-Sep-12            10          9        2                 0          1
# 4    10-Sep-12            11         11        1                 4          4
# ..         ...           ...        ...      ...               ...        ...
# 331  24-Sep-12             2          3        3                 0          2
# 332  24-Sep-12             3          3        3                 0          1
# 333  24-Sep-12             4          1        1                 0          0
# 334  24-Sep-12             5          4        2                 1          1
# 335  24-Sep-12             6          9        1                 2          2
#
#      Unique Drivers            Datetime  trips_per_driver
# 0                 9 2012-09-10 07:00:00          0.222222
# 1                14 2012-09-10 08:00:00          0.142857
# 2                14 2012-09-10 09:00:00          0.000000
# 3                14 2012-09-10 10:00:00          0.000000
# 4                11 2012-09-10 11:00:00          0.363636
# ..              ...                 ...               ...
# 331               0 2012-09-24 02:00:00               NaN
# 332               0 2012-09-24 03:00:00               NaN
# 333               0 2012-09-24 04:00:00               NaN
# 334               3 2012-09-24 05:00:00          0.333333
# 335               7 2012-09-24 06:00:00          0.285714
#
# [336 rows x 9 columns]

# %%
df_agg[['Unique Drivers','Eyeballs ']].plot(style='.-')
plt.xticks(np.arange(min(df_agg.index), max(df_agg.index)+1, 1.0))

plt.show()

# %% [markdown]
# ### We see in the table and plot above that both the supply and demand are at the minimum at 04:00 hrs
